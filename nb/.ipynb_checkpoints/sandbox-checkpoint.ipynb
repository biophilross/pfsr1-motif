# %%
from pandas import *

# %%
data1 = read_table("fimo_all_transcripts_SBM1/norm_hits_SBM1.txt", index_col='ID')
data2 = read_table("fimo_all_transcripts_SBM2/norm_hits_SBM2.txt", index_col='ID')
sbm1 = read_csv("fimo_all_transcripts_SBM1/SBM1_outliers.csv", index_col='ID')
sbm2 = read_csv("fimo_all_transcripts_SBM2/SBM2_outliers.csv", index_col='ID')

# %%
sbm1.sort('Hits', ascending=False).head(20)
# Out:
#                Hits  Length  Normalized  \
# ID
# PF3D7_1362700   121    6120    0.019771
# PF3D7_1441100    85     684    0.124269
# PF3D7_0935200    77    3444    0.022358
# PF3D7_0404300    64    1896    0.033755
# PF3D7_1318300    64    5523    0.011588
# PF3D7_0106700    63    4305    0.014634
# PF3D7_1217300    59    2886    0.020444
# PF3D7_1358100    52    2205    0.023583
# PF3D7_1450500    51    4962    0.010278
# PF3D7_1024800    50    4395    0.011377
#
#                                                          Product
# ID
# PF3D7_1362700         conservedPlasmodiumprotein,unknownfunction
# PF3D7_1441100         conservedPlasmodiumprotein,unknownfunction
# PF3D7_0935200                                 sec-1familyprotein
# PF3D7_0404300         conservedPlasmodiumprotein,unknownfunction
# PF3D7_1318300         conservedPlasmodiumprotein,unknownfunction
# PF3D7_0106700  smallribosomalsubunitassemblingAARP2protein(AA...
# ...

# %%
sbm1.sort('Normalized', ascending=False).head(20)
# Out:
#                Hits  Length  Normalized  \
# ID
# PF3D7_1441100    85     684    0.124269
# PF3D7_1336700    24     477    0.050314
# PF3D7_0813300    42     948    0.044304
# PF3D7_0532100    20     546    0.036630
# PF3D7_0203700    47    1320    0.035606
# PF3D7_0404300    64    1896    0.033755
# PF3D7_1140200    44    1344    0.032738
# PF3D7_0729400    40    1251    0.031974
# PF3D7_1342400    32    1158    0.027634
# PF3D7_0517200    48    1899    0.025276
#
#                                                      Product
# ID
# PF3D7_1441100     conservedPlasmodiumprotein,unknownfunction
# PF3D7_1336700     conservedPlasmodiumprotein,unknownfunction
# PF3D7_0813300     conservedPlasmodiumprotein,unknownfunction
# PF3D7_0532100      earlytranscribedmembraneprotein5(ETRAMP5)
# PF3D7_0203700  nucleolarpreribosomalassemblyprotein,putative
# PF3D7_0404300     conservedPlasmodiumprotein,unknownfunction
# PF3D7_1140200     conservedPlasmodiumprotein,unknownfunction
# ...

# %%
sbm2.sort('Hits', ascending=False).head(10)
# Out:
#                  Hits  Length  Normalized  \
# ID
# PF3D7_1038400     236   28692    0.008225
# PF3D7_0526600      50   13575    0.003683
# PF3D7_0220000      22    4677    0.004704
# PF3D7_1035900      18    1701    0.010582
# PF3D7_0102200      16    3258    0.004911
# PF3D7_1035300      15    3702    0.004052
# PF3D7_1230900      11    2814    0.003909
# PF3D7_1149200       9    3273    0.002750
# PF3D7_1149100.2     7    1350    0.005185
# PF3D7_1149100.1     7    1353    0.005174
#
#                                                       Product
# ID
# PF3D7_1038400              gametocyte-specificprotein(Pf11-1)
# PF3D7_0526600      conservedPlasmodiumprotein,unknownfunction
# PF3D7_0220000                        liverstageantigen3(LSA3)
# PF3D7_1035900           probableprotein,unknownfunction(M566)
# PF3D7_0102200    ring-infectederythrocytesurfaceantigen(RESA)
# PF3D7_1035300                    glutamate-richprotein(GLURP)
# ...

# %%
sbm2.sort('Normalized', ascending=False).head(10)
# Out:
#                  Hits  Length  Normalized  \
# ID
# PF3D7_1330900       1      80    0.012500
# PF3D7_0702800       1      84    0.011905
# PF3D7_1035900      18    1701    0.010582
# mal_rna_19          1     101    0.009901
# PF3D7_0314100.2     2     213    0.009390
# PF3D7_0308400       1     119    0.008403
# PF3D7_1217800       2     243    0.008230
# PF3D7_1038400     236   28692    0.008225
# PF3D7_1416900       3     444    0.006757
# PF3D7_0402900       2     300    0.006667
#
#                                                  Product
# ID
# PF3D7_1330900                    smallnucleolarRNAsnoR17
# PF3D7_0702800                               tRNATyrosine
# PF3D7_1035900      probableprotein,unknownfunction(M566)
# mal_rna_19                      unspecifiedproduct(RNA8)
# PF3D7_0314100.2  vesicletransportv-SNAREprotein,putative
# PF3D7_0308400                          U4SpliceosomalRNA
# PF3D7_1217800                 zincfingerprotein,putative
# ...

# %%
sbm2.loc['PF3D7_1038400'] # sbm1.loc[] can't find this gene
# Out:
# Hits                                         236
# Length                                     28692
# Normalized                           0.008225289
# Product       gametocyte-specificprotein(Pf11-1)
# Name: PF3D7_1038400, dtype: object

# %%
data1.Normalized.std()
# Out:
# 0.0034201947138751765
